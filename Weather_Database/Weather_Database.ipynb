# %% [markdown]
# # RICE-VIRT-DATA-PT-05-2022-U-B-MW Module 6 Challenge

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data
# ## Code Summary
# - **Purpose  :** Collect and analyze weather data across cities worldwide, using 500 or more unique & random cities
# - **Created  :** 2022 Jun 19 22:41:05 UTC (Meghan E. Hull)
# - **Modified :** 2022 Jun 20 05:45:44 UTC (Meghan E. Hull)
#
# ## Dependencies

# %%
# Import the dependencies.
import pandas as pd
import time
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from scipy.stats import linregress

# %% [markdown]
# ## Inputs & API keys

# %%
# Add the directory above current directory to list of directories where Python will look for modules
import sys; sys.path.insert(0, '..')

# Import the API key from main directory
from config import weather_api_key

# Specify the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# %% [markdown]
# # Retreive Weather Data for 500+ Random Cities
# ## 1. Generate more than 2,000 random latitudes and longitudes

# %%
# Parameters for latitude & longitude ranges
lat_low=-90
lat_high=90
lng_low=-180
lng_high=180
no_gen=2000

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=lat_low, high=lat_high, size=no_gen)
lngs = np.random.uniform(low=lng_low, high=lng_high, size=no_gen)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ## 2. List the nearest city to the latitudes and longitudes

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %% [markdown]
# ## 3. Use OpenWeatherMap API to request current weather data from each unique city in cities list

# %%
# Creater start of URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval for " + str(len(cities)) + " Cities")
print("-----------------------------")

# Set start time (sec0nds)
t_o=time.time()

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
## 4. Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except Exception as e:
#         print(e)
        print("City not found. Skipping...")
        pass

# Set end time (sec0nds)
t_f=time.time()

# Find elapsed time (sec0nds)
t_del=t_f-t_o
t_del_hr=int(t_del/3600)
t_del_min=int(t_del/60)-t_del_hr*60
t_del_sec=round(t_del-t_del_hr*3600-t_del_min*60,2)
t_del_str=str(t_del_hr) + ":" + str(t_del_min) + ":" + str(t_del_sec) + " (" + str(round(t_del,2)) + " sec)"

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Completed     ")
print("-----------------------------")
print("Time Elapsed: " + t_del_str)
print("Data found for " + str(len(city_data)) + " of " + str(len(cities)) + " cities")
print("-----------------------------")
# Out:
# Beginning Data Retrieval for 743 Cities
# -----------------------------
# Processing Record 1 of Set 1 | bulgan
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | alofi
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | muyezerskiy
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | cairns
# Processing Record 11 of Set 1 | concordia
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | anloga
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | diffa
# Processing Record 20 of Set 1 | geraldton
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | maragogi
# Processing Record 24 of Set 1 | awbari
# Processing Record 25 of Set 1 | mount gambier
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | kinshasa
# Processing Record 28 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | voznesenye
# Processing Record 31 of Set 1 | pacific grove
# Processing Record 32 of Set 1 | bodrum
# Processing Record 33 of Set 1 | luneville
# Processing Record 34 of Set 1 | tongzi
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | kita
# Processing Record 37 of Set 1 | xining
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | taitung
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | saint anthony
# Processing Record 44 of Set 1 | penzance
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | siocon
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | klaksvik
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | sovetskiy
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | robertsport
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | tautira
# Processing Record 11 of Set 2 | pringsewu
# Processing Record 12 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | gwembe
# Processing Record 19 of Set 2 | mana
# Processing Record 20 of Set 2 | paamiut
# Processing Record 21 of Set 2 | vitimskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | luanda
# Processing Record 23 of Set 2 | batagay
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | biak
# Processing Record 26 of Set 2 | assiniboia
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | marsh harbour
# Processing Record 29 of Set 2 | beidao
# Processing Record 30 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 2 | carlos antonio lopez
# Processing Record 32 of Set 2 | pitimbu
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | kautokeino
# Processing Record 35 of Set 2 | severo-yeniseyskiy
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | zhangye
# Processing Record 38 of Set 2 | katsuura
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | alice springs
# Processing Record 44 of Set 2 | kofarnihon
# City not found. Skipping...
# Processing Record 45 of Set 2 | lavrentiya
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | aquiraz
# Processing Record 48 of Set 2 | kavaratti
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | byron bay
# Processing Record 1 of Set 3 | ajdabiya
# Processing Record 2 of Set 3 | mandalgovi
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | naze
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | kidal
# Processing Record 8 of Set 3 | aloleng
# Processing Record 9 of Set 3 | karaton
# Processing Record 10 of Set 3 | kenai
# Processing Record 11 of Set 3 | high rock
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | gulf gate estates
# Processing Record 16 of Set 3 | madras
# Processing Record 17 of Set 3 | dudinka
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | kosh-agach
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | provideniya
# Processing Record 23 of Set 3 | iralaya
# Processing Record 24 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | auki
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | odoyev
# Processing Record 30 of Set 3 | skjervoy
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | baneasa
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | qaqortoq
# Processing Record 35 of Set 3 | topchikha
# Processing Record 36 of Set 3 | nanortalik
# Processing Record 37 of Set 3 | kushiro
# Processing Record 38 of Set 3 | meaford
# Processing Record 39 of Set 3 | akureyri
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | taoudenni
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | muli
# Processing Record 44 of Set 3 | darnah
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | manokwari
# Processing Record 47 of Set 3 | urumqi
# Processing Record 48 of Set 3 | pundri
# Processing Record 49 of Set 3 | ellensburg
# Processing Record 50 of Set 3 | jaranwala
# Processing Record 1 of Set 4 | bilma
# Processing Record 2 of Set 4 | atasu
# Processing Record 3 of Set 4 | shenzhen
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | killarney
# Processing Record 6 of Set 4 | zyryanka
# Processing Record 7 of Set 4 | tebingtinggi
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | vao
# Processing Record 10 of Set 4 | savannakhet
# Processing Record 11 of Set 4 | suluq
# Processing Record 12 of Set 4 | katangli
# Processing Record 13 of Set 4 | herat
# Processing Record 14 of Set 4 | seddon
# Processing Record 15 of Set 4 | zhigansk
# Processing Record 16 of Set 4 | necochea
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | caravelas
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | praia
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | casino
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | ferme-neuve
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | eyl
# Processing Record 27 of Set 4 | dongsheng
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | roald
# Processing Record 30 of Set 4 | san-pedro
# Processing Record 31 of Set 4 | russellville
# Processing Record 32 of Set 4 | thinadhoo
# Processing Record 33 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 4 | hamada
# Processing Record 35 of Set 4 | north bend
# Processing Record 36 of Set 4 | san quintin
# Processing Record 37 of Set 4 | dargaville
# Processing Record 38 of Set 4 | okhotsk
# Processing Record 39 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 4 | jalu
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | muros
# Processing Record 43 of Set 4 | mezen
# Processing Record 44 of Set 4 | banamba
# Processing Record 45 of Set 4 | chifeng
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | along
# Processing Record 48 of Set 4 | rio gallegos
# Processing Record 49 of Set 4 | kaoma
# Processing Record 50 of Set 4 | lazaro cardenas
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | udachnyy
# Processing Record 4 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 5 | wenatchee
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | ondjiva
# Processing Record 9 of Set 5 | kelo
# Processing Record 10 of Set 5 | tuatapere
# Processing Record 11 of Set 5 | brae
# Processing Record 12 of Set 5 | bredasdorp
# Processing Record 13 of Set 5 | tual
# Processing Record 14 of Set 5 | moussoro
# Processing Record 15 of Set 5 | avera
# Processing Record 16 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 5 | tiksi
# Processing Record 18 of Set 5 | newcastle
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | horsham
# Processing Record 23 of Set 5 | ucluelet
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | saldanha
# Processing Record 26 of Set 5 | stonewall
# Processing Record 27 of Set 5 | belmonte
# Processing Record 28 of Set 5 | karabash
# Processing Record 29 of Set 5 | koygorodok
# Processing Record 30 of Set 5 | madinat sittah uktubar
# Processing Record 31 of Set 5 | nome
# Processing Record 32 of Set 5 | sao jose da coroa grande
# Processing Record 33 of Set 5 | lakatoro
# Processing Record 34 of Set 5 | carnarvon
# Processing Record 35 of Set 5 | hofn
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | pauini
# Processing Record 38 of Set 5 | angra
# City not found. Skipping...
# Processing Record 39 of Set 5 | scarborough
# Processing Record 40 of Set 5 | hualmay
# Processing Record 41 of Set 5 | hilo
# Processing Record 42 of Set 5 | haines junction
# Processing Record 43 of Set 5 | bakchar
# Processing Record 44 of Set 5 | dhidhdhoo
# Processing Record 45 of Set 5 | touros
# Processing Record 46 of Set 5 | vallentuna
# Processing Record 47 of Set 5 | yeoryiani
# City not found. Skipping...
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | duluth
# Processing Record 50 of Set 5 | santa isabel do rio negro
# Processing Record 1 of Set 6 | labuhan
# Processing Record 2 of Set 6 | broome
# Processing Record 3 of Set 6 | hami
# Processing Record 4 of Set 6 | enshi
# Processing Record 5 of Set 6 | huanren
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | mirnyy
# Processing Record 8 of Set 6 | tim
# Processing Record 9 of Set 6 | tilichiki
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | alghero
# Processing Record 12 of Set 6 | auxerre
# Processing Record 13 of Set 6 | gazojak
# Processing Record 14 of Set 6 | korla
# Processing Record 15 of Set 6 | durban
# Processing Record 16 of Set 6 | flinders
# Processing Record 17 of Set 6 | coihaique
# Processing Record 18 of Set 6 | padang
# Processing Record 19 of Set 6 | lagoa
# Processing Record 20 of Set 6 | gat
# Processing Record 21 of Set 6 | vichy
# Processing Record 22 of Set 6 | semey
# Processing Record 23 of Set 6 | belaya gora
# Processing Record 24 of Set 6 | pangnirtung
# Processing Record 25 of Set 6 | vostok
# Processing Record 26 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 6 | fortuna
# Processing Record 28 of Set 6 | baghdad
# Processing Record 29 of Set 6 | martapura
# Processing Record 30 of Set 6 | takoradi
# Processing Record 31 of Set 6 | nizwa
# Processing Record 32 of Set 6 | yar-sale
# Processing Record 33 of Set 6 | rimbey
# Processing Record 34 of Set 6 | jackson
# Processing Record 35 of Set 6 | hashtrud
# Processing Record 36 of Set 6 | obninsk
# Processing Record 37 of Set 6 | inhambane
# Processing Record 38 of Set 6 | pisco
# Processing Record 39 of Set 6 | abbotsford
# Processing Record 40 of Set 6 | minudasht
# Processing Record 41 of Set 6 | egvekinot
# Processing Record 42 of Set 6 | buraydah
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | konde
# Processing Record 45 of Set 6 | batticaloa
# Processing Record 46 of Set 6 | luwuk
# Processing Record 47 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 6 | guerrero negro
# Processing Record 49 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 6 | batsfjord
# Processing Record 1 of Set 7 | maracacume
# Processing Record 2 of Set 7 | portsmouth
# Processing Record 3 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 7 | salta
# Processing Record 5 of Set 7 | barao de melgaco
# Processing Record 6 of Set 7 | zhanaozen
# Processing Record 7 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 7 | maniitsoq
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | karratha
# Processing Record 11 of Set 7 | orem
# Processing Record 12 of Set 7 | dutlwe
# Processing Record 13 of Set 7 | kantunilkin
# Processing Record 14 of Set 7 | najran
# Processing Record 15 of Set 7 | lilongwe
# Processing Record 16 of Set 7 | burns lake
# Processing Record 17 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 18 of Set 7 | hunucma
# Processing Record 19 of Set 7 | kibi
# Processing Record 20 of Set 7 | afanasyevo
# City not found. Skipping...
# Processing Record 21 of Set 7 | ilulissat
# Processing Record 22 of Set 7 | chernyshevskiy
# Processing Record 23 of Set 7 | terralba
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | coquimbo
# Processing Record 26 of Set 7 | asfi
# Processing Record 27 of Set 7 | xifeng
# Processing Record 28 of Set 7 | det udom
# Processing Record 29 of Set 7 | fort nelson
# Processing Record 30 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 7 | bonavista
# Processing Record 32 of Set 7 | port hedland
# Processing Record 33 of Set 7 | zalari
# Processing Record 34 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 35 of Set 7 | zeya
# Processing Record 36 of Set 7 | tura
# Processing Record 37 of Set 7 | goderich
# Processing Record 38 of Set 7 | liaoyang
# Processing Record 39 of Set 7 | totness
# Processing Record 40 of Set 7 | faanui
# Processing Record 41 of Set 7 | bridlington
# Processing Record 42 of Set 7 | burnie
# Processing Record 43 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 7 | frontera
# Processing Record 45 of Set 7 | severo-kurilsk
# Processing Record 46 of Set 7 | sabha
# Processing Record 47 of Set 7 | leshukonskoye
# Processing Record 48 of Set 7 | jinji
# Processing Record 49 of Set 7 | romitan
# Processing Record 50 of Set 7 | bandarbeyla
# Processing Record 1 of Set 8 | bud
# Processing Record 2 of Set 8 | bosaso
# Processing Record 3 of Set 8 | arraial do cabo
# Processing Record 4 of Set 8 | khor
# Processing Record 5 of Set 8 | makakilo city
# Processing Record 6 of Set 8 | amparafaravola
# Processing Record 7 of Set 8 | fukue
# Processing Record 8 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 8 | beringovskiy
# Processing Record 10 of Set 8 | leningradskiy
# Processing Record 11 of Set 8 | kawalu
# Processing Record 12 of Set 8 | ayagoz
# Processing Record 13 of Set 8 | wattegama
# Processing Record 14 of Set 8 | papara
# Processing Record 15 of Set 8 | ancud
# Processing Record 16 of Set 8 | yingcheng
# Processing Record 17 of Set 8 | nagua
# Processing Record 18 of Set 8 | numata
# Processing Record 19 of Set 8 | iqaluit
# Processing Record 20 of Set 8 | yerbogachen
# Processing Record 21 of Set 8 | savalou
# Processing Record 22 of Set 8 | saskylakh
# Processing Record 23 of Set 8 | nemuro
# Processing Record 24 of Set 8 | mecca
# Processing Record 25 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 8 | beloha
# Processing Record 27 of Set 8 | xianyang
# Processing Record 28 of Set 8 | hernani
# Processing Record 29 of Set 8 | tigil
# Processing Record 30 of Set 8 | sarrebourg
# Processing Record 31 of Set 8 | niesky
# Processing Record 32 of Set 8 | shubarshi
# Processing Record 33 of Set 8 | tazovskiy
# Processing Record 34 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 35 of Set 8 | kemijarvi
# Processing Record 36 of Set 8 | dayong
# Processing Record 37 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 8 | tiarei
# Processing Record 39 of Set 8 | starkville
# Processing Record 40 of Set 8 | marawi
# Processing Record 41 of Set 8 | shepsi
# Processing Record 42 of Set 8 | ous
# Processing Record 43 of Set 8 | bratsk
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | bubaque
# Processing Record 46 of Set 8 | belomorsk
# Processing Record 47 of Set 8 | sandakan
# Processing Record 48 of Set 8 | nioro
# Processing Record 49 of Set 8 | voh
# Processing Record 50 of Set 8 | homer
# Processing Record 1 of Set 9 | port lincoln
# Processing Record 2 of Set 9 | vila velha
# Processing Record 3 of Set 9 | honningsvag
# Processing Record 4 of Set 9 | okha
# Processing Record 5 of Set 9 | hasaki
# Processing Record 6 of Set 9 | barra do bugres
# Processing Record 7 of Set 9 | sussex
# Processing Record 8 of Set 9 | quelimane
# Processing Record 9 of Set 9 | the pas
# Processing Record 10 of Set 9 | springbok
# Processing Record 11 of Set 9 | tucumcari
# Processing Record 12 of Set 9 | puerto padre
# Processing Record 13 of Set 9 | hamilton
# Processing Record 14 of Set 9 | chicama
# Processing Record 15 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 9 | shahgarh
# Processing Record 17 of Set 9 | riviere-au-renard
# Processing Record 18 of Set 9 | sembe
# Processing Record 19 of Set 9 | ryotsu
# Processing Record 20 of Set 9 | owando
# Processing Record 21 of Set 9 | dukat
# Processing Record 22 of Set 9 | de aar
# Processing Record 23 of Set 9 | clyde river
# Processing Record 24 of Set 9 | linxia
# Processing Record 25 of Set 9 | atar
# Processing Record 26 of Set 9 | miracema do tocantins
# Processing Record 27 of Set 9 | carnot
# Processing Record 28 of Set 9 | coffs harbour
# Processing Record 29 of Set 9 | vilyuysk
# Processing Record 30 of Set 9 | half moon bay
# Processing Record 31 of Set 9 | lebedinyy
# Processing Record 32 of Set 9 | nizhniy odes
# Processing Record 33 of Set 9 | skala
# Processing Record 34 of Set 9 | harper
# Processing Record 35 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 9 | pareora
# Processing Record 37 of Set 9 | buchanan
# Processing Record 38 of Set 9 | aswan
# Processing Record 39 of Set 9 | nicoya
# Processing Record 40 of Set 9 | kultuk
# Processing Record 41 of Set 9 | east london
# Processing Record 42 of Set 9 | houma
# Processing Record 43 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 9 | huilong
# Processing Record 45 of Set 9 | remanso
# Processing Record 46 of Set 9 | nakamura
# Processing Record 47 of Set 9 | ixtapa
# Processing Record 48 of Set 9 | baruun-urt
# Processing Record 49 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 50 of Set 9 | saint-augustin
# Processing Record 1 of Set 10 | barcelos
# Processing Record 2 of Set 10 | santa maria
# Processing Record 3 of Set 10 | coruripe
# Processing Record 4 of Set 10 | lasa
# Processing Record 5 of Set 10 | caconda
# Processing Record 6 of Set 10 | rapid valley
# Processing Record 7 of Set 10 | caborca
# Processing Record 8 of Set 10 | makushino
# Processing Record 9 of Set 10 | fengcheng
# Processing Record 10 of Set 10 | mehamn
# Processing Record 11 of Set 10 | havelock
# Processing Record 12 of Set 10 | mwense
# Processing Record 13 of Set 10 | sur
# Processing Record 14 of Set 10 | richards bay
# Processing Record 15 of Set 10 | shitanjing
# Processing Record 16 of Set 10 | kitimat
# Processing Record 17 of Set 10 | galeana
# Processing Record 18 of Set 10 | andenes
# Processing Record 19 of Set 10 | kiunga
# Processing Record 20 of Set 10 | belle fourche
# Processing Record 21 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 10 | nijar
# Processing Record 23 of Set 10 | guayaramerin
# Processing Record 24 of Set 10 | yulara
# Processing Record 25 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 10 | prince rupert
# Processing Record 27 of Set 10 | edd
# Processing Record 28 of Set 10 | dingle
# Processing Record 29 of Set 10 | somerset
# Processing Record 30 of Set 10 | resistencia
# Processing Record 31 of Set 10 | ensley
# Processing Record 32 of Set 10 | puerto carreno
# Processing Record 33 of Set 10 | mount isa
# Processing Record 34 of Set 10 | ust-koksa
# Processing Record 35 of Set 10 | kibondo
# Processing Record 36 of Set 10 | whitianga
# Processing Record 37 of Set 10 | te anau
# Processing Record 38 of Set 10 | san cristobal
# Processing Record 39 of Set 10 | talca
# Processing Record 40 of Set 10 | ostrovnoy
# Processing Record 41 of Set 10 | eureka
# Processing Record 42 of Set 10 | gombong
# Processing Record 43 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 44 of Set 10 | pachino
# Processing Record 45 of Set 10 | kudahuvadhoo
# Processing Record 46 of Set 10 | trelew
# Processing Record 47 of Set 10 | deer park
# Processing Record 48 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 10 | rumonge
# Processing Record 50 of Set 10 | mayumba
# Processing Record 1 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 11 | giresun
# Processing Record 4 of Set 11 | itarantim
# Processing Record 5 of Set 11 | bowen
# Processing Record 6 of Set 11 | baykit
# Processing Record 7 of Set 11 | chiclana
# Processing Record 8 of Set 11 | dodge city
# Processing Record 9 of Set 11 | hongjiang
# Processing Record 10 of Set 11 | saint-pierre
# Processing Record 11 of Set 11 | shiyan
# Processing Record 12 of Set 11 | samarai
# Processing Record 13 of Set 11 | teahupoo
# Processing Record 14 of Set 11 | bushehr
# Processing Record 15 of Set 11 | acari
# Processing Record 16 of Set 11 | tromso
# Processing Record 17 of Set 11 | kostomuksha
# Processing Record 18 of Set 11 | punta de piedra
# Processing Record 19 of Set 11 | temiscaming
# Processing Record 20 of Set 11 | tjaereborg
# Processing Record 21 of Set 11 | negotin
# Processing Record 22 of Set 11 | channel-port aux basques
# Processing Record 23 of Set 11 | kirakira
# Processing Record 24 of Set 11 | kulhudhuffushi
# Processing Record 25 of Set 11 | grimari
# City not found. Skipping...
# Processing Record 26 of Set 11 | sorland
# Processing Record 27 of Set 11 | itarema
# Processing Record 28 of Set 11 | taltal
# Processing Record 29 of Set 11 | sioux lookout
# Processing Record 30 of Set 11 | igrim
# Processing Record 31 of Set 11 | hudiksvall
# Processing Record 32 of Set 11 | tutoia
# Processing Record 33 of Set 11 | batavia
# Processing Record 34 of Set 11 | aabybro
# Processing Record 35 of Set 11 | innisfail
# Processing Record 36 of Set 11 | atherton
# Processing Record 37 of Set 11 | mercedes
# Processing Record 38 of Set 11 | birmitrapur
# Processing Record 39 of Set 11 | kamenka
# Processing Record 40 of Set 11 | andijon
# Processing Record 41 of Set 11 | zharkent
# Processing Record 42 of Set 11 | sarti
# Processing Record 43 of Set 11 | maarianhamina
# Processing Record 44 of Set 11 | saint-joseph
# Processing Record 45 of Set 11 | roma
# Processing Record 46 of Set 11 | holme
# Processing Record 47 of Set 11 | mazagao
# Processing Record 48 of Set 11 | chumikan
# Processing Record 49 of Set 11 | kardla
# Processing Record 50 of Set 11 | port-cartier
# Processing Record 1 of Set 12 | batagay-alyta
# Processing Record 2 of Set 12 | la ronge
# Processing Record 3 of Set 12 | oliveira dos brejinhos
# Processing Record 4 of Set 12 | vicuna
# Processing Record 5 of Set 12 | pozo colorado
# Processing Record 6 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 12 | souillac
# Processing Record 8 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 12 | aguia branca
# Processing Record 11 of Set 12 | superior
# Processing Record 12 of Set 12 | aykhal
# Processing Record 13 of Set 12 | moindou
# Processing Record 14 of Set 12 | malmyzh
# Processing Record 15 of Set 12 | yantai
# Processing Record 16 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 17 of Set 12 | miles city
# Processing Record 18 of Set 12 | walvis bay
# Processing Record 19 of Set 12 | broken hill
# Processing Record 20 of Set 12 | kalmunai
# Processing Record 21 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 22 of Set 12 | mineros
# Processing Record 23 of Set 12 | inyonga
# Processing Record 24 of Set 12 | chantada
# Processing Record 25 of Set 12 | inuvik
# Processing Record 26 of Set 12 | emerald
# Processing Record 27 of Set 12 | phan thiet
# Processing Record 28 of Set 12 | cervo
# Processing Record 29 of Set 12 | ayan
# Processing Record 30 of Set 12 | amberley
# Processing Record 31 of Set 12 | mandiana
# Processing Record 32 of Set 12 | grand gaube
# Processing Record 33 of Set 12 | balabac
# Processing Record 34 of Set 12 | portland
# Processing Record 35 of Set 12 | cayenne
# Processing Record 36 of Set 12 | hovd
# Processing Record 37 of Set 12 | callaway
# Processing Record 38 of Set 12 | port-gentil
# Processing Record 39 of Set 12 | xichang
# Processing Record 40 of Set 12 | bereda
# Processing Record 41 of Set 12 | algeciras
# Processing Record 42 of Set 12 | dunedin
# Processing Record 43 of Set 12 | mus
# Processing Record 44 of Set 12 | asyut
# Processing Record 45 of Set 12 | kismayo
# Processing Record 46 of Set 12 | piterka
# Processing Record 47 of Set 12 | qasigiannguit
# Processing Record 48 of Set 12 | dali
# Processing Record 49 of Set 12 | onda
# Processing Record 50 of Set 12 | kununurra
# Processing Record 1 of Set 13 | cap-aux-meules
# Processing Record 2 of Set 13 | vanavara
# Processing Record 3 of Set 13 | brunico
# Processing Record 4 of Set 13 | sakakah
# Processing Record 5 of Set 13 | shache
# Processing Record 6 of Set 13 | buala
# Processing Record 7 of Set 13 | puerto escondido
# Processing Record 8 of Set 13 | thayetmyo
# Processing Record 9 of Set 13 | davila
# Processing Record 10 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 13 | tabory
# Processing Record 12 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 13 of Set 13 | merauke
# Processing Record 14 of Set 13 | acapulco
# Processing Record 15 of Set 13 | bundaberg
# Processing Record 16 of Set 13 | westport
# Processing Record 17 of Set 13 | ulaanbaatar
# Processing Record 18 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 13 | khoy
# Processing Record 20 of Set 13 | kheda
# Processing Record 21 of Set 13 | amahai
# Processing Record 22 of Set 13 | bolshevik
# Processing Record 23 of Set 13 | epe
# Processing Record 24 of Set 13 | alekseyevsk
# Processing Record 25 of Set 13 | angoche
# Processing Record 26 of Set 13 | chichester
# Processing Record 27 of Set 13 | havre
# Processing Record 28 of Set 13 | asau
# Processing Record 29 of Set 13 | uvalde
# Processing Record 30 of Set 13 | kargasok
# Processing Record 31 of Set 13 | yeppoon
# Processing Record 32 of Set 13 | santiago
# Processing Record 33 of Set 13 | ust-shonosha
# Processing Record 34 of Set 13 | boa vista
# Processing Record 35 of Set 13 | sungaipenuh
# Processing Record 36 of Set 13 | pangoa
# Processing Record 37 of Set 13 | paoua
# Processing Record 38 of Set 13 | virginia beach
# Processing Record 39 of Set 13 | ixhuatan
# Processing Record 40 of Set 13 | bafq
# Processing Record 41 of Set 13 | ketchikan
# Processing Record 42 of Set 13 | kungurtug
# Processing Record 43 of Set 13 | chiredzi
# Processing Record 44 of Set 13 | bonfim
# Processing Record 45 of Set 13 | phichit
# Processing Record 46 of Set 13 | somvarpet
# Processing Record 47 of Set 13 | nezhinka
# Processing Record 48 of Set 13 | solnechnyy
# Processing Record 49 of Set 13 | tabo-o
# City not found. Skipping...
# Processing Record 50 of Set 13 | klamath falls
# Processing Record 1 of Set 14 | kingston
# Processing Record 2 of Set 14 | mananjary
# Processing Record 3 of Set 14 | muroto
# Processing Record 4 of Set 14 | manta
# Processing Record 5 of Set 14 | hit
# Processing Record 6 of Set 14 | tomatlan
# Processing Record 7 of Set 14 | metro
# Processing Record 8 of Set 14 | jerez
# Processing Record 9 of Set 14 | nalut
# Processing Record 10 of Set 14 | kjollefjord
# Processing Record 11 of Set 14 | nouadhibou
# Processing Record 12 of Set 14 | santa ana
# Processing Record 13 of Set 14 | bandar-e anzali
# Processing Record 14 of Set 14 | kerema
# Processing Record 15 of Set 14 | luancheng
# Processing Record 16 of Set 14 | oistins
# Processing Record 17 of Set 14 | sabya
# Processing Record 18 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 19 of Set 14 | jiuquan
# Processing Record 20 of Set 14 | ati
# Processing Record 21 of Set 14 | raudeberg
# Processing Record 22 of Set 14 | do rud
# City not found. Skipping...
# Processing Record 23 of Set 14 | port hardy
# Processing Record 24 of Set 14 | umm lajj
# Processing Record 25 of Set 14 | sarangani
# Processing Record 26 of Set 14 | chiman
# Processing Record 27 of Set 14 | cap malheureux
# Processing Record 28 of Set 14 | oron
# Processing Record 29 of Set 14 | cozumel
# Processing Record 30 of Set 14 | celestun
# Processing Record 31 of Set 14 | coxim
# Processing Record 32 of Set 14 | ambilobe
# Processing Record 33 of Set 14 | gusau
# Processing Record 34 of Set 14 | kisangani
# Processing Record 35 of Set 14 | miyako
# Processing Record 36 of Set 14 | palmer
# Processing Record 37 of Set 14 | southampton
# Processing Record 38 of Set 14 | krasnoselkup
# Processing Record 39 of Set 14 | shambu
# Processing Record 40 of Set 14 | pedreiras
# Processing Record 41 of Set 14 | the valley
# Processing Record 42 of Set 14 | san juan del sur
# Processing Record 43 of Set 14 | alvdal
# Processing Record 44 of Set 14 | filingue
# Processing Record 45 of Set 14 | malanje
# Processing Record 46 of Set 14 | porto velho
# Processing Record 47 of Set 14 | colares
# Processing Record 48 of Set 14 | noumea
# Processing Record 49 of Set 14 | kristiinankaupunki
# Processing Record 50 of Set 14 | khorramshahr
# Processing Record 1 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 15 | manicore
# Processing Record 3 of Set 15 | zarubino
# Processing Record 4 of Set 15 | flin flon
# Processing Record 5 of Set 15 | freeport
# Processing Record 6 of Set 15 | sabang
# Processing Record 7 of Set 15 | verkh-usugli
# Processing Record 8 of Set 15 | oranjemund
# Processing Record 9 of Set 15 | thunder bay
# Processing Record 10 of Set 15 | ferrol
# Processing Record 11 of Set 15 | havre-saint-pierre
# Processing Record 12 of Set 15 | mogadishu
# Processing Record 13 of Set 15 | cabanas
# Processing Record 14 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 15 of Set 15 | yacuiba
# Processing Record 16 of Set 15 | manitouwadge
# Processing Record 17 of Set 15 | anadyr
# Processing Record 18 of Set 15 | smithers
# Processing Record 19 of Set 15 | magadan
# Processing Record 20 of Set 15 | sangar
# Processing Record 21 of Set 15 | nayagarh
# Processing Record 22 of Set 15 | sembakung
# Processing Record 23 of Set 15 | amapa
# Processing Record 24 of Set 15 | sinnamary
# Processing Record 25 of Set 15 | kabardinka
# Processing Record 26 of Set 15 | poum
# Processing Record 27 of Set 15 | bizhbulyak
# Processing Record 28 of Set 15 | vari
# Processing Record 29 of Set 15 | akhmim
# Processing Record 30 of Set 15 | itoman
# Processing Record 31 of Set 15 | tambun
# Processing Record 32 of Set 15 | bilibino
# Processing Record 33 of Set 15 | santa cruz
# Processing Record 34 of Set 15 | tecoanapa
# Processing Record 35 of Set 15 | parthenay
# Processing Record 36 of Set 15 | brownsville
# Processing Record 37 of Set 15 | bambanglipuro
# Processing Record 38 of Set 15 | greenville
# Processing Record 39 of Set 15 | moratuwa
# Processing Record 40 of Set 15 | moose factory
# Processing Record 41 of Set 15 | college
# Processing Record 42 of Set 15 | srednekolymsk
# Processing Record 43 of Set 15 | dinsor
# City not found. Skipping...
# -----------------------------
# Data Retrieval Completed
# -----------------------------
# Time Elapsed: 0:17:35.16 (1055.16 sec)
# Data found for 683 of 743 cities
# -----------------------------

# %% [markdown]
# # Add Weather Data a DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# # Reorder columns
# new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
# city_data_df=city_data_df[new_column_order]

#Check dataframe
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bulgan      MN  48.8125  103.5347     72.90        42          52
# 1   Codrington      AU -38.2667  141.9667     54.19        80         100
# 2      Rikitea      PF -23.1203 -134.9692     71.58        58          76
# 3        Alofi      NU -19.0595 -169.9187     76.89        94          75
# 4     Hermanus      ZA -34.4187   19.2345     44.80        84           0
# 5       Barrow      US  71.2906 -156.7887     55.42        71           0
# 6  Muyezerskiy      RU  63.9333   31.6500     49.41        74          64
# 7        Airai      TL  -8.9266  125.4092     72.23        43          65
# 8       Cairns      AU -16.9167  145.7667     83.07        67         100
# 9    Concordia      AR -31.3930  -58.0209     38.79       100           9
#
#    Wind Speed Current Description
# 0        5.46       broken clouds
# 1       20.40     overcast clouds
# 2       19.71       broken clouds
# 3        4.61       broken clouds
# 4       13.20           clear sky
# 5       11.50           clear sky
# 6        8.46       broken clouds
# 7        4.29       broken clouds
# 8       16.11     overcast clouds
# 9        5.06           clear sky

# %% [markdown]
# # Store data in an output csv

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
